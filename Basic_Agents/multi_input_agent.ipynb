# %% [markdown]
# <a href="https://colab.research.google.com/github/Utkarsh-Aggarwal/Agentic_AI/blob/master/multi_input_agent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langgraph

# %%
from typing import TypedDict,List
from langgraph.graph import StateGraph

# %%
class AgentState(TypedDict):
  values:List[int]
  name:str
  result:str

# %%
def process_values( state:AgentState)->AgentState:
  """ this function handels multiple diffrent input """
  state["result"] = f"Hi there {state['name']}! your Sum = {sum(state["values"])}"
  return state

# %%
graph = StateGraph(AgentState)
graph.add_node("processor",process_values)
graph.set_entry_point("processor")#Set the value
graph.set_finish_point("processor")

app = graph.compile()

# %%
answers = app.invoke({"values":[1,2,3,4,5],"name":"Steve"})

# %%
print(answers)
